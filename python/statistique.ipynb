# %% [markdown]
# # Analyse statistique des instances

# %%
from WarehouseLoader import *
from statistique import *
import numpy as np
import math
import pandas as pd

# %%
l = distance_aisles(["warehouse_toy", "warehouse_big_category", "warehouse_big_family", "warehouse_big_market"])

# %%
stats_df = stat_aisles(l)
stats_df[stats_df["instance"] == "warehouse_big_market"]
# Out:
#                  instance  nb_racks  nb_prod       min       p10    median  \
# 230  warehouse_big_market        16        1  0.000000  0.000000  0.015625
# 231  warehouse_big_market        16        2  0.000000  0.003906  0.029297
# 232  warehouse_big_market        16        3  0.000000  0.007812  0.089844
# 233  warehouse_big_market        16        4  0.000000  0.027344  0.128906
# 234  warehouse_big_market        16        5  0.000000  0.078125  0.160156
# ..                    ...       ...      ...       ...       ...       ...
# 340  warehouse_big_market        38       34  0.576453  0.714067  0.847095
# 341  warehouse_big_market        38       35  0.636086  0.752294  0.905199
# 342  warehouse_big_market        38       36  0.680428  0.792049  0.963303
# 343  warehouse_big_market        38       37  0.738532  0.837920  1.021407
# 344  warehouse_big_market        38       38  0.796636  0.886239  1.079511
#
#           p90       max      mean       std
# ...

# %%
plot_stats_by_instance_nb_racks(stats_df)
