# %% [markdown]
# # Test de l'importation + résolution + écriture dans un fichier .sol

# %%
from Naif import *

file_name = "../data/warehouse_toy/"
solver = Naif(file_name)

# %% [markdown]
# # Test de l'écriture SVG

# %%
solver.write_svg()
# Out:
# True

# %% [markdown]
# # Test du chargement d'une solution
# Attention à bien mettre à jour l'identifiant.

# %%
solver.load_solution("warehouse_toy", "Naif", id = "582")
solver.write_svg()
# Out:
# An error occurred while reading the file: [Errno 2] No such file or directory: '../solutions/warehouse_toy_Naif_582.sol'
# True

# %%
print("".join("_" for _ in range(80)))
# Out:
# ________________________________________________________________________________
