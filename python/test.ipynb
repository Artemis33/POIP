# %% [markdown]
# # Test de l'importation + résolution

# %%
from Naif import *

file_name = "../data/warehouse_toy/"
solver = Naif(file_name)
# Out:
# WarehouseInstance(num_racks=20, capacity=24, num_products=15, num_orders=25)
